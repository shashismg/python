# %% [markdown]
# <a href="https://colab.research.google.com/github/shashismg/python/blob/main/pandas/pandas_movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('movies.csv')
df.head(7)
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
# 5                     The Shawshank Redemption  Hollywood          1994
# 6                                 Interstellar  Hollywood          2014
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# ...

# %%
df.tail(4)
# Out:
#                         title   industry  release_year  imdb_rating  \
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
df.sample(4)
# Out:
#                        title   industry  release_year  imdb_rating  \
# 12             The Godfather  Hollywood          1972          9.2
# 9                    Titanic  Hollywood          1997          7.9
# 18    Avengers: Infinity War  Hollywood          2018          8.4
# 5   The Shawshank Redemption  Hollywood          1994          9.3
#
#                        studio  budget  revenue      unit currency language
# 12         Paramount Pictures     7.2    291.0  Millions      USD  English
# 9          Paramount Pictures   200.0   2202.0  Millions      USD  English
# 18             Marvel Studios   400.0   2048.0  Millions      USD  English
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df[0:1]
# Out:
#              title   industry  release_year  imdb_rating  \
# 0  Pather Panchali  Bollywood          1955          8.3
#
#                       studio   budget   revenue       unit currency language
# 0  Government of West Bengal  70000.0  100000.0  Thousands      INR  Bengali

# %%
df.shape
# Out:
# (37, 10)

# %%
df.head(1)
# Out:
#              title   industry  release_year  imdb_rating  \
# 0  Pather Panchali  Bollywood          1955          8.3
#
#                       studio   budget   revenue       unit currency language
# 0  Government of West Bengal  70000.0  100000.0  Thousands      INR  Bengali

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         37 non-null     object
#  1   industry      37 non-null     object
#  2   release_year  37 non-null     int64
#  3   imdb_rating   36 non-null     float64
#  4   studio        34 non-null     object
#  5   budget        37 non-null     float64
#  6   revenue       37 non-null     float64
#  7   unit          37 non-null     object
#  8   currency      37 non-null     object
#  9   language      37 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 3.0+ KB

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df.imdb_rating.min(), df.imdb_rating.max(), df.imdb_rating.mean(), df.imdb_rating.median(), df.imdb_rating.std(), df.imdb_rating.count()
# Out:
# (1.9,
#  9.3,
#  np.float64(7.919444444444445),
#  8.1,
#  1.2049468143436146,
#  np.int64(36))

# %%
df_b = df[df.industry == 'Bollywood']
df_h = df[df.industry == 'Hollywood']

# %%
df[df.industry == 'Bollywood'].imdb_rating.min()
# Out:
# 1.9

# %%
df[df['industry' == 'Bollywood']].imdb_rating.min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-21-579475879.py in <cell line: 0>()
# ----> 1 df[df['industry' == 'Bollywood']].imdb_rating.min()
#
# ...

# %%
df_b.head()
# Out:
#                           title   industry  release_year  imdb_rating  \
# 0               Pather Panchali  Bollywood          1955          8.3
# 21  Dilwale Dulhania Le Jayenge  Bollywood          1995          8.0
# 22                     3 Idiots  Bollywood          2009          8.4
# 23     Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 24             Bajirao Mastani   Bollywood          2015          7.2
#
#                        studio   budget   revenue       unit currency language
# 0   Government of West Bengal  70000.0  100000.0  Thousands      INR  Bengali
# 21             Yash Raj Films    400.0    2000.0   Millions      INR    Hindi
# 22         Vinod Chopra Films    550.0    4000.0   Millions      INR    Hindi
# 23         Dharma Productions    390.0    1360.0   Millions      INR    Hindi
# 24                        NaN      1.4       3.5   Billions      INR    Hindi

# %%
df_h.head()
# Out:
#                                          title   industry  release_year  \
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
# 5                     The Shawshank Redemption  Hollywood          1994
#
#    imdb_rating                     studio  budget  revenue      unit currency  \
# 1          7.0             Marvel Studios   200.0    954.8  Millions      USD
# 2          6.8             Marvel Studios   165.0    644.8  Millions      USD
# 3          7.9             Marvel Studios   180.0    854.0  Millions      USD
# 4          6.8             Marvel Studios   250.0    670.0  Millions      USD
# 5          9.3  Castle Rock Entertainment    25.0     73.3  Millions      USD
#
#   language
# 1  English
# 2  English
# 3  English
# 4  English
# ...

# %%
df_b.imdb_rating.min(), df_b.imdb_rating.max(), df_b.imdb_rating.mean(), df_b.imdb_rating.median(), df_b.imdb_rating.std(), df_b.imdb_rating.count()
# Out:
# (1.9,
#  8.4,
#  np.float64(7.656250000000001),
#  8.1,
#  1.5760578458081207,
#  np.int64(16))

# %%
df_h.imdb_rating.min(), df_h.imdb_rating.max(), df_h.imdb_rating.mean(), df_h.imdb_rating.median(), df_h.imdb_rating.std(), df_h.imdb_rating.count()
# Out:
# (6.8,
#  9.3,
#  np.float64(8.130000000000003),
#  8.3,
#  0.7800809674575286,
#  np.int64(20))

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df.industry.unique(
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.language.unique()
# Out:
# array(['Bengali', 'English', 'Hindi', 'Kannada', 'Telugu'], dtype=object)

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df.language.value_counts()
# Out:
# language
# English    20
# Hindi      12
# Telugu      3
# Bengali     1
# Kannada     1
# Name: count, dtype: int64

# %%
df[ ["title", "imdb_rating", "industry"] ].head()
# Out:
#                                          title  imdb_rating   industry
# 0                              Pather Panchali          8.3  Bollywood
# 1  Doctor Strange in the Multiverse of Madness          7.0  Hollywood
# 2                        Thor: The Dark World           6.8  Hollywood
# 3                              Thor: Ragnarok           7.9  Hollywood
# 4                      Thor: Love and Thunder           6.8  Hollywood

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language
# 0      INR  Bengali
# 1      USD  English
# 2      USD  English
# ...

# %%
df.release_year > 2010
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# Name: release_year, dtype: bool

# %%
df[ (df.release_year > 2000) & (df.release_year < 2010)]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 7   The Pursuit of Happyness  Hollywood          2006          8.0
# 11                    Avatar  Hollywood          2009          7.8
# 13           The Dark Knight  Hollywood          2008          9.0
# 22                  3 Idiots  Bollywood          2009          8.4
# 23  Kabhi Khushi Kabhie Gham  Bollywood          2001          7.4
# 25          Taare Zameen Par  Bollywood          2007          8.3
# 26       Munna Bhai M.B.B.S.  Bollywood          2003          8.1
#
#                       studio  budget  revenue      unit currency language
# 7          Columbia Pictures    55.0    307.1  Millions      USD  English
# 11          20th Century Fox   237.0   2847.0  Millions      USD  English
# 13                   Syncopy   185.0   1006.0  Millions      USD  English
# 22        Vinod Chopra Films   550.0   4000.0  Millions      INR    Hindi
# ...

# %%
df[ df.studio == 'Marvel Studios' ]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 17                            Avengers: Endgame  Hollywood          2019
# 18                       Avengers: Infinity War  Hollywood          2018
# 19           Captain America: The First Avenger  Hollywood          2011
# 20          Captain America: The Winter Soldier  Hollywood          2014
#
#     imdb_rating          studio  budget  revenue      unit currency language
# 1           7.0  Marvel Studios   200.0    954.8  Millions      USD  English
# 2           6.8  Marvel Studios   165.0    644.8  Millions      USD  English
# 3           7.9  Marvel Studios   180.0    854.0  Millions      USD  English
# ...

# %%
df.studio.unique()
# Out:
# array(['Government of West Bengal', 'Marvel Studios',
#        'Castle Rock Entertainment', 'Warner Bros. Pictures',
#        'Columbia Pictures', 'Universal Pictures  ', 'Paramount Pictures',
#        'Liberty Films', '20th Century Fox', 'Syncopy',
#        'Universal Pictures', nan, 'Yash Raj Films', 'Vinod Chopra Films',
#        'Dharma Productions', 'Vinod Chopra Productions', 'Zee Studios',
#        'Salman Khan Films', 'Hombale Films', 'Mythri Movie Makers',
#        'DVV Entertainment', 'Arka Media Works'], dtype=object)

# %%
df.describe()
# Out:
#        release_year  imdb_rating        budget        revenue
# count     37.000000    36.000000     37.000000      37.000000
# mean    2007.027027     7.919444   2084.975135    4117.135135
# std       17.657995     1.204947  11477.487145   16372.462682
# min     1946.000000     1.900000      1.000000       3.100000
# 25%     2001.000000     7.800000     15.500000     263.100000
# 50%     2014.000000     8.100000    165.000000     701.800000
# 75%     2018.000000     8.400000    250.000000    2000.000000
# max     2022.000000     9.300000  70000.000000  100000.000000

# %%
df[ df.imdb_rating == df.imdb_rating.max() | df.imdb_rating == df.imdb_rating.min()]
# Out:
#                       title   industry  release_year  imdb_rating  \
# 5  The Shawshank Redemption  Hollywood          1994          9.3
#
#                       studio  budget  revenue      unit currency language
# 5  Castle Rock Entertainment    25.0     73.3  Millions      USD  English

# %%
df[ (df.imdb_rating == df.imdb_rating.max()) | (df.imdb_rating == df.imdb_rating.min())]
# Out:
#                        title   industry  release_year  imdb_rating  \
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 31                    Race 3  Bollywood          2018          1.9
#
#                        studio  budget  revenue      unit currency language
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 31          Salman Khan Films     1.8      3.1  Billions      INR    Hindi

# %%
df["age"] = 2028 - df.release_year

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age
# 0      INR  Bengali   73
# 1      USD  English    6
# ...

# %%
df["profit"] = df.revenue - df.budget

# %%
df.head()
# Out:
#                                          title   industry  release_year  \
# 0                              Pather Panchali  Bollywood          1955
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                        Thor: The Dark World   Hollywood          2013
# 3                              Thor: Ragnarok   Hollywood          2017
# 4                      Thor: Love and Thunder   Hollywood          2022
#
#    imdb_rating                     studio   budget   revenue       unit  \
# 0          8.3  Government of West Bengal  70000.0  100000.0  Thousands
# 1          7.0             Marvel Studios    200.0     954.8   Millions
# 2          6.8             Marvel Studios    165.0     644.8   Millions
# 3          7.9             Marvel Studios    180.0     854.0   Millions
# 4          6.8             Marvel Studios    250.0     670.0   Millions
#
#   currency language  age   profit  profit1
# 0      INR  Bengali   73  30000.0  30000.0
# ...

# %%
df ["profit1"] = df.apply(lambda row: row.revenue - row.budget, axis = 1)

# %%
df = pd.read_csv("stock_data.csv", header=1, na_values=["not available", "n.a."])

# %%
df.head()
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df["pe"] = df["price"]/df["eps"]
df.head()
# Out:
#   tickers    eps  revenue   price         people         pe
# 0   GOOGL  27.82       87   845.0     larry page  30.373832
# 1     WMT   4.61      484    65.0            NaN  14.099783
# 2    MSFT  -1.00       85    64.0     bill gates -64.000000
# 3    RIL     NaN       50  1023.0  mukesh ambani        NaN
# 4    TATA   5.60       -1     NaN     ratan tata        NaN

# %%
df.to_csv("new_pe.csv", index=False)

# %%
import ast,sys
input_str = input()
#Type your code here

n = len(input_str)
message1 = ''
message2 = ''

for i in range(0, n, 2):
    message1 = message1 + input_str[i]
    message2 = message2 + input_str[i+1]

i=0
for char in message1:
    if char == '#':
        message1 = message1[0:i]
        break
    else:
        i = i + 1

i=0
for char in message2:
    if char == '#':
        message2 = message2[0:i]
        break
    else:
        i = i + 1

print(message1, message2)
# Out:
# cmhuemmbbauir#
# chembur mumbai

# %%
def remove_duplicates(s):
    output_string = ''

    for char in s:
        if char in output_string:
            continue
        else:
            output_string = output_string + char

    return output_string

s="aabbcc"
remove_duplicates(s)
# Out:
# 'abc'

# %%
print(bool(1), bool(-8), bool(1.67), bool(False))
# Out:
# True True True False

# %%
len('Python and R are used in data science')
# Out:
# 37

# %%
print('My name is {John} and I am {30} years old'.format())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-b5a0dc9397ba> in <cell line: 0>()
# ----> 1 print('My name is {John} and I am {30} years old'.format())
#
# KeyError: 'John'

# %%
print(4%100,4//100,4/100)
# Out:
# 4 0 0.04

# %%
print(4//100)
# Out:
# 0

# %%
df.imdb_rating.min(), df.imdb_rating.max(), df.imdb_rating.mean(), df.imdb_rating.median(), df.imdb_rating.std(), df.imdb_rating.count()
# Out:
# (1.9,
#  9.3,
#  np.float64(7.919444444444445),
#  8.1,
#  1.2049468143436146,
#  np.int64(36))

# %%
df.head(1)
# Out:
#              title   industry  release_year  imdb_rating  \
# 0  Pather Panchali  Bollywood          1955          8.3
#
#                       studio   budget   revenue       unit currency language
# 0  Government of West Bengal  70000.0  100000.0  Thousands      INR  Bengali

# %%
df.industry.unique()
# Out:
# array(['Bollywood', 'Hollywood'], dtype=object)

# %%
df.industry.value_counts()
# Out:
# industry
# Hollywood    20
# Bollywood    17
# Name: count, dtype: int64

# %%
df[df['industry' == 'Hollywood']].imdb_rating.min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-17-3550368839.py in <cell line: 0>()
# ----> 1 df[df['industry' == 'Hollywood']].imdb_rating.min()
#
# ...

# %%
df.industry == 'Bollywood'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# Name: industry, dtype: bool

# %%
df[df.industry == 'Bollywood'].head(3)
# Out:
#                           title   industry  release_year  imdb_rating  \
# 0               Pather Panchali  Bollywood          1955          8.3
# 21  Dilwale Dulhania Le Jayenge  Bollywood          1995          8.0
# 22                     3 Idiots  Bollywood          2009          8.4
#
#                        studio   budget   revenue       unit currency language
# 0   Government of West Bengal  70000.0  100000.0  Thousands      INR  Bengali
# 21             Yash Raj Films    400.0    2000.0   Millions      INR    Hindi
# 22         Vinod Chopra Films    550.0    4000.0   Millions      INR    Hindi

# %%
df[df.industry == 'Hollywood'].imdb_rating.min()
# Out:
# 6.8

# %%
df[df['industry'] == 'Hollywood'].imdb_rating.min()
# Out:
# 6.8

# %%
df[df['industry' == 'Hollywood']].imdb_rating.min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-29-3550368839.py in <cell line: 0>()
# ----> 1 df[df['industry' == 'Hollywood']].imdb_rating.min()
#
# ...

# %%
df.head(1)
# Out:
#              title   industry  release_year  imdb_rating  \
# 0  Pather Panchali  Bollywood          1955          8.3
#
#                       studio   budget   revenue       unit currency language
# 0  Government of West Bengal  70000.0  100000.0  Thousands      INR  Bengali

# %%
df.industry == 'Hollywood'
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# Name: industry, dtype: bool

# %%
dfs = df.industry == 'Hollywood'

# %%
df[dfs]
# Out:
#                                           title   industry  release_year  \
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# 12                                The Godfather  Hollywood          1972
# ...

# %%
df_h = df[df.industry == 'Hollywood']

# %%
df_h.count()
# Out:
# title           20
# industry        20
# release_year    20
# imdb_rating     20
# studio          19
# budget          20
# revenue         20
# unit            20
# currency        20
# language        20
# dtype: int64

# %%
df_h.head(1)
# Out:
#                                          title   industry  release_year  \
# 1  Doctor Strange in the Multiverse of Madness  Hollywood          2022
#
#    imdb_rating          studio  budget  revenue      unit currency language
# 1          7.0  Marvel Studios   200.0    954.8  Millions      USD  English

# %%
df_b = df[df.industry == 'Bollywood']
df_h = df[df.industry == 'Hollywood']

df_b.shape, df_h.shape
# Out:
# ((17, 10), (20, 10))

# %%
df_b.imdb_rating.min(), df_b.imdb_rating.max(), df_b.imdb_rating.mean(), df_b.imdb_rating.median(), df_b.imdb_rating.std(), df_b.imdb_rating.count()
# Out:
# (1.9,
#  8.4,
#  np.float64(7.656250000000001),
#  8.1,
#  1.5760578458081207,
#  np.int64(16))

# %%
df_h.imdb_rating.min(), df_h.imdb_rating.max(), df_h.imdb_rating.mean(), df_h.imdb_rating.median(), df_h.imdb_rating.std(), df_h.imdb_rating.count()
# Out:
# (6.8,
#  9.3,
#  np.float64(8.130000000000003),
#  8.3,
#  0.7800809674575286,
#  np.int64(20))

# %%
b_min_rating = df_b.imdb_rating.min()
df_b[df_b.imdb_rating == b_min_rating]
# Out:
#      title   industry  release_year  imdb_rating             studio  budget  \
# 31  Race 3  Bollywood          2018          1.9  Salman Khan Films     1.8
#
#     revenue      unit currency language
# 31      3.1  Billions      INR    Hindi
